# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiruthika2006-devil/AI_Based_Disease_Prediction_System/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, SimpleRNN, Embedding

# 1. LOAD AND PREPROCESS DATA
# Replace the URL below with your raw file or a local path like 'disease_dataset.csv'
DATA_URL = "https://raw.githubusercontent.com/Kiruthika2006-devil/AI_Based_Disease_Prediction_System/main/disease_dataset.csv"

try:
    df = pd.read_csv(DATA_URL)
    print("Dataset loaded successfully!")
except Exception as e:
    print(f"Could not load from URL, please ensure the path is correct. Error: {e}")
    # Fallback to local file if needed: df = pd.read_csv('disease_dataset.csv')

# Drop completely empty columns if they exist
df = df.dropna(axis=1, how='all')

# Assume the last column contains the disease names (e.g., 'prognosis' or 'disease')
X = df.iloc[:, :-1].values  # Features (Symptoms: 0s and 1s)
y = df.iloc[:, -1].values   # Target (Disease Labels)

# Encode categorical text labels into integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(np.unique(y_encoded))

# Split into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

print(f"Number of symptoms (features): {X.shape[1]}")
print(f"Number of target diseases (classes): {num_classes}")


# 2. MODEL 1: ARTIFICIAL NEURAL NETWORK (ANN)
print("\n--- Training Artificial Neural Network (ANN) ---")

ann_model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(num_classes, activation='softmax')  # Softmax for multi-class classification
])

ann_model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# Train the ANN
ann_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1, verbose=1)

# Evaluate ANN
ann_preds = np.argmax(ann_model.predict(X_test), axis=-1)
ann_acc = accuracy_score(y_test, ann_preds)
print(f"\nANN Test Accuracy: {ann_acc * 100:.2f}%")


# 3. MODEL 2: RECURRENT NEURAL NETWORK (RNN)
print("\n--- Training Recurrent Neural Network (RNN) ---")

# For RNN, data must be 3D: (samples, timesteps, features)
# We treat each symptom feature as a timestep with 1 element
X_train_rnn = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test_rnn = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

rnn_model = Sequential([
    SimpleRNN(64, activation='tanh', input_shape=(X_train_rnn.shape[1], 1), return_sequences=False),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])

rnn_model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# Train the RNN
rnn_model.fit(X_train_rnn, y_train, epochs=15, batch_size=64, validation_split=0.1, verbose=1)

# Evaluate RNN
rnn_preds = np.argmax(rnn_model.predict(X_test_rnn), axis=-1)
rnn_acc = accuracy_score(y_test, rnn_preds)
print(f"\nRNN Test Accuracy: {rnn_acc * 100:.2f}%")

# 4. FINAL COMPARISON REPORT
print("\n=== Final Performance Comparison ===")
print(f"ANN Accuracy: {ann_acc * 100:.2f}%")
print(f"RNN Accuracy: {rnn_acc * 100:.2f}%")

print("\nDetailed ANN Classification Report:")
print(classification_report(y_test, ann_preds, target_names=label_encoder.classes_))
# Out:
# Dataset loaded successfully!
# Number of symptoms (features): 5
# Number of target diseases (classes): 8
#
# --- Training Artificial Neural Network (ANN) ---
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1456 - loss: 4.1387 - val_accuracy: 0.1275 - val_loss: 2.0796
# Epoch 2/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1675 - loss: 2.1236 - val_accuracy: 0.1075 - val_loss: 2.0802
# Epoch 3/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2133 - loss: 1.9926 - val_accuracy: 0.3325 - val_loss: 1.7756
# Epoch 4/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2764 - loss: 1.7099 - val_accuracy: 0.5325 - val_loss: 1.2561
# Epoch 5/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3703 - loss: 1.4170 - val_accuracy: 0.6425 - val_loss: 1.0503
# Epoch 6/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4411 - loss: 1.2207 - val_accuracy: 0.6850 - val_loss: 0.9314
# Epoch 7/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4925 - loss: 1.0980 - val_accuracy: 0.7275 - val_loss: 0.8260
# Epoch 8/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5361 - loss: 1.0076 - val_accuracy: 0.6900 - val_loss: 0.7229
# Epoch 9/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5989 - loss: 0.8949 - val_accuracy: 0.7700 - val_loss: 0.6281
# Epoch 10/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6300 - loss: 0.7960 - val_accuracy: 0.7800 - val_loss: 0.5930
# Epoch 11/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6600 - loss: 0.7461 - val_accuracy: 0.7800 - val_loss: 0.5534
# Epoch 12/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6917 - loss: 0.6779 - val_accuracy: 0.7875 - val_loss: 0.5144
# Epoch 13/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6994 - loss: 0.6617 - val_accuracy: 0.7950 - val_loss: 0.4983
# Epoch 14/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7253 - loss: 0.6224 - val_accuracy: 0.7825 - val_loss: 0.4759
# Epoch 15/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7144 - loss: 0.6076 - val_accuracy: 0.8300 - val_loss: 0.4532
# Epoch 16/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7333 - loss: 0.5795 - val_accuracy: 0.8075 - val_loss: 0.4628
# Epoch 17/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7436 - loss: 0.5639 - val_accuracy: 0.8100 - val_loss: 0.4402
# Epoch 18/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7481 - loss: 0.5437 - val_accuracy: 0.7925 - val_loss: 0.4520
# Epoch 19/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7589 - loss: 0.5336 - val_accuracy: 0.8300 - val_loss: 0.4061
# Epoch 20/20
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7642 - loss: 0.5236 - val_accuracy: 0.8100 - val_loss: 0.4171
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# ANN Test Accuracy: 81.60%
#
# --- Training Recurrent Neural Network (RNN) ---
# Epoch 1/15
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5314 - loss: 1.3301 - val_accuracy: 0.7725 - val_loss: 0.6878
# Epoch 2/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7636 - loss: 0.6165 - val_accuracy: 0.7925 - val_loss: 0.4734
# Epoch 3/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8025 - loss: 0.4851 - val_accuracy: 0.8100 - val_loss: 0.4112
# Epoch 4/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8056 - loss: 0.4499 - val_accuracy: 0.8300 - val_loss: 0.3870
# Epoch 5/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8189 - loss: 0.4221 - val_accuracy: 0.8300 - val_loss: 0.3619
# Epoch 6/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8256 - loss: 0.4031 - val_accuracy: 0.8400 - val_loss: 0.3690
# Epoch 7/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8247 - loss: 0.4002 - val_accuracy: 0.8450 - val_loss: 0.3540
# Epoch 8/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8283 - loss: 0.3956 - val_accuracy: 0.8375 - val_loss: 0.3460
# Epoch 9/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8328 - loss: 0.3891 - val_accuracy: 0.8425 - val_loss: 0.3398
# Epoch 10/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8361 - loss: 0.3804 - val_accuracy: 0.8475 - val_loss: 0.3359
# Epoch 11/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8325 - loss: 0.3788 - val_accuracy: 0.8550 - val_loss: 0.3207
# Epoch 12/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8400 - loss: 0.3728 - val_accuracy: 0.8475 - val_loss: 0.3460
# Epoch 13/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8367 - loss: 0.3727 - val_accuracy: 0.8500 - val_loss: 0.3272
# Epoch 14/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8442 - loss: 0.3646 - val_accuracy: 0.8425 - val_loss: 0.3216
# Epoch 15/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8408 - loss: 0.3630 - val_accuracy: 0.8550 - val_loss: 0.3302
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# RNN Test Accuracy: 83.20%
#
# === Final Performance Comparison ===
# ANN Accuracy: 81.60%
# RNN Accuracy: 83.20%
#
# Detailed ANN Classification Report:
#               precision    recall  f1-score   support
#
#       Asthma       0.55      0.80      0.65       125
#    Body Ache       1.00      0.98      0.99       125
#  Common Cold       0.83      0.62      0.71       125
#        Cough       0.84      0.66      0.74       125
#       Dengue       0.93      1.00      0.96       125
#      Malaria       1.00      0.94      0.97       125
# Normal Fever       0.81      0.63      0.71       125
#   Runny Nose       0.72      0.90      0.80       125
#
#     accuracy                           0.82      1000
#    macro avg       0.84      0.82      0.82      1000
# weighted avg       0.84      0.82      0.82      1000
